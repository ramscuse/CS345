# %% [markdown]
# # CS 345 Exercise: labeled data
#
# **Instructions:** Complete the exercises in this notebook and submit it via Canvas.
#
# In this exercise, you are will gain experience in generating synthetic data and observing their different characteristics. To begin the goal is to create a labeled dataset in 2-Dimensions or 3-Dimensions using the sklearn function [make_classification](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html#sklearn.datasets.make_classification). Please go read up on what this function does.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import numpy as np

# %% [markdown]
# ### Labeled data in two dimensions
#
# In this part, you are going to generate labeled datasets with different characteristics by tuning the parameters in the scikit-learn **make_classification** function.

# %% [markdown]
# In Cell 02, create a labled 2D data by using `make_classification`. Please use the following parameters to make_classification to set up your dataset. Plot it by using Matplotlib's [scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) function.

# %%
# Code Cell 02
n_samples = 1000
n_features=2
n_informative=2
n_redundant=0
n_repeated=0
n_classes=2
n_clusters_per_class=1
class_sep=1
flip_y=0
random_state=42
# below call make_classification with these parameters and plot
# a scatter plot of the data
x,y = make_classification(n_samples = 1000, n_features = 2, n_informative = 2, 
                          n_redundant = 0, n_repeated= 0, n_classes = 2, 
                          n_clusters_per_class = 1, class_sep = 1, flip_y = 0, random_state = 42)
plt.scatter(x[:,0], x[:,1], alpha=1.0);

# %% [markdown]
# The parameter `class_sep` controls the separation of the classes, and hence changes the difficulty of the classification task. The data points can be easily separable when having a higher class separation.
#
# In Cell 03, create a labled two dimensional dataset by using the function make_classification. Please keep all the key variable unchanged except **class_sep**. Set it to a value that will guarantee accurate classification.
# Plot the data by using a **scatter** plot.

# %% [markdown]
# ### Class separation

# %%
# Code Cell 03
class_sep = 0.1

# below write code that demonstrates that using a higher class_sep
# leads to an easier classification problem.
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=100, n_features=2, n_informative=2, 
                          n_redundant=0, n_repeated=0, 
                          n_classes=2, n_clusters_per_class=1, 
                          class_sep=0.4, random_state=1)
plt.scatter(X[:,0], X[:,1], c=y, alpha=0.7, s=50, cmap='coolwarm');

# %%
X,y = make_classification(n_samples=100, n_features=2, n_informative=2, 
                          n_redundant=0, n_repeated=0, 
                          n_classes=2, n_clusters_per_class=1, 
                          class_sep=0.1, random_state=1)
plt.scatter(X[:,0], X[:,1], c=y, alpha=0.7, s=50, cmap='coolwarm');

# %% [markdown]
# ### Class imbalance

# %% [markdown]
# In real world situation you often encounter data that is imbalanced, i.e. one class has many more examples than the other.  This is simulated using the parameter **weights**.  In Cell 04, please use the following parameter values we provide here to set up your dataset. Plot the data using a scatter plot.

# %%
# Code Cell 04
n_samples = 1000
n_features=2
n_informative=2
n_redundant=0
n_repeated=0
n_classes=2
n_clusters_per_class=1
class_sep=2
flip_y=0
weights=[0.9,0.1] 
random_state=42
X,y = make_classification(n_samples=1000, n_features=2, n_informative=2, 
                          n_redundant=0, n_repeated=0, 
                          n_classes=2, n_clusters_per_class=1, 
                          class_sep=2, flip_y=0, weights=[0.9,0.1], random_state=42)
plt.scatter(X[:,0], X[:,1], c=y, alpha=0.7, cmap='coolwarm');

# %% [markdown]
# ### Label noise

# %% [markdown]
# In real world situations, data is often mislabeled.  Use the parameter **flip_y** to simulate this kind of noise. In Cell05, please use the following the parameters provided here to set up your dataset. Plot the data by using a scatter plot.

# %%
# Code Cell 05

n_samples = 1000
n_features=2
n_informative=2
n_redundant=0
n_repeated=0
n_classes=2
n_clusters_per_class=1
class_sep=2
flip_y=0.2
random_state=42
X,y = make_classification(n_samples=1000, n_features=2, n_informative=2, 
                          n_redundant=0, n_repeated=0, 
                          n_classes=2, n_clusters_per_class=1, 
                          class_sep=2, flip_y=0.2, random_state=42)

plt.scatter(X[:,0], X[:,1], c=y, alpha=0.4, cmap='coolwarm');

# %% [markdown]
# The number of features that are relevant to the classification problem can be controled by tuning the parameter **n_informative**. In Cell 06, please use the following parameters provided here to set up your dataset.
# Plot the data by using a scatter plot.

# %%
# Code Cell 06

n_samples = 1000
n_features=2
n_informative=1
n_redundant=0
n_repeated=0
n_classes=2
n_clusters_per_class=1
class_sep=2
flip_y=0
random_state=42

X,y = make_classification(n_samples=1000, n_features=2, n_informative=1, 
                          n_redundant=0, n_repeated=0, 
                          n_classes=2, n_clusters_per_class=1, 
                          class_sep=2, flip_y=0, random_state=42)

plt.scatter(X[:,0], X[:,1], c=y, alpha=0.4, cmap='coolwarm');
